# %%
print('hola')
# Out:
# hola

# %%
def saludar():
    print('hola')

saludar()
# Out:
# hola

# %%
palabra = 'hola'
def imprimir_palabra():
    print(palabra)

imprimir_palabra()
# Out:
# hola

# %%
#definir 2 variables con int(input((numero 1, numero 2))
# definir funcion sumar(n1,n2):
# opcion1: n3=n1+n2 
# opcion2: print(n1+n2)


#llamar a la funcion  sumar (numero 1, numero 2)

numero1=int(input('ingresa un numero'))
numero2=int(input('ingrese un numero'))

def sumar(n1,n2):
    n3= n1+n2
    print(n3)
sumar(numero1,numero2)
# Out:
# 2

# %%
#crear una variable para las letras
# letra1 definir variable
# letra2 

#definir la funcion verificar_letra(l1,l2):

# if l1== l2
   #print ( las letras son iguales.)
# else :
   #print('las letras son diferentes')

#llamar a la funcion con sus argumentos

letra1=input('ingresa una letra')
letra2=input('ingrese una letra')

def comparar_letras(letra1, letra2):
    if letra1 == letra2:
       print("Las letras son iguales")
    else:
        print("Las letras son diferentes")

comparar_letras(letra1,letra2)
# Out:
# Las letras son iguales

# %%
def sumar(n1,n2):
    resultado_suma= n1+n2
    return resultado_suma

print(type(sumar(2,2)))

resultado= sumar(5,8)
print(resultado)
# Out:
# <class 'int'>
# 13

# %%
letra1=input('ingresa una letra o numero')
letra2=input('ingrese una letra o numero')
def verificar(palabra, numero):  
    if len (palabra)==numero:
       return True
    else: 
       return False
    
palabra= 'toyota'
numero=int('6')

verificar(palabra,numero)
# Out:
# True

# %%
#crear función que revise si una palabra contiene una letra
letra=()
numero=()
def palabra(letra,numero):  
    if letra == "numero":
        print({letra})

# %%
contenido= 'calle'
contenido2 = 'a'
def revisar_letra(palabra, letra):
    if letra in palabra:
        return f"[{letra}]"
    else:
        return letra
print(revisar_letra(contenido,contenido2))
print(contenido,contenido2)
# Out:
# [a]
# calle a

# %%
#defininr una variable palabra = input()
#convertir palabra a lista con list(palabra)
 

# creamos otr lista llamada : palaras_ingresadas ={}
#palabras_ingresadas.append(lista_de_palabra)
#convertir esa palabra a una lista con sus caracteres con list()


palabra1 = input("Ingresa una palabra: ")
mi_lista = list(palabra1)
print(mi_lista)
palabras_ingresadas = []
# Out:
# ['s', 'i']

# %%
palabras_ingresadas = []

for _ in range(3):
    palabra = input("Ingresa una palabra: ")
    lista_letras = list(palabra)
    palabras_ingresadas.append(lista_letras)
    print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a'], ['q', 'u', 'e']]
# [['h', 'o', 'l', 'a'], ['q', 'u', 'e'], ['t', 'a', 'l']]
