# %%
print('hola')
# Out:
# hola

# %%
# Challenge diccionario
Datos_Personales ={}
Datos_Personales['nombre']  = input ('Introduzca su nombre')
print(Datos_Personales)
Datos_Personales ={}
Datos_Personales['edad']  = input ('Introduzca su edad')
print(Datos_Personales)
Datos_Personales ={}
Datos_Personales['sexo']  = input ('Introduzca su sexo')
print(Datos_Personales)
Datos_Personales ={}
Datos_Personales[' teléfono']  = input ('teléfono')
print(Datos_Personales)
Datos_Personales ={}
Datos_Personales['correo electronico']  = input ('correo electronico')
print(Datos_Personales)
# Out:
# {'nombre': 'hi'}
# {'edad': 'hi'}
# {'sexo': 'hi'}
# {' teléfono': 'hi'}
# {'correo electronico': 'hi'}

# %%
Datos_Personales = {}

Datos_Personales['Dato'] = input('Introduzca el dato que quiera crear: ')
print(Datos_Personales)


clave = input('¿Qué dato quiere modificar?: ')
nuevo_valor = input('Introduzca el nuevo valor: ')

Datos_Personales[clave] = nuevo_valor
print(Datos_Personales)
# Out:
# {'Dato': 'hi'}
# {'Dato': 'hi', 'hi': 'ol'}

# %%
class Caballo :
    patas = 4
    cabeza = 1
    cola= 1
def __init__ (self , nombre, color):
    self.nombre= nombre
    self.nombre= color
# Out:
#   Cell In[30], line 7
#     print(caballo)
#     ^
# IndentationError: expected an indented block after function definition on line 5

# %%
class yoite:
    def hablar(self):
        print("Cuando hablo, digo: Hola")

    def mover(self):
        print("Cuando me muevo,corro")


yo = yoite()

yo.hablar()
yo.mover()
# Out:
# Cuando hablo, digo: Hola
# Cuando me muevo,corro

# %%
#Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un heroe y un villano.
#Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#Ejemplo: Yo me llamo pepito y tengo super fuerza
#Ejemplo: Yo me llamo juanito y puedo volar

class Heroe:
    def __init__(self, nombre):
        self.nombre = nombre

    def presentarse(self):
        return f"Yo me llamo {self.nombre} y tengo super fuerza."


class Villano:
    def __init__(self, nombre):
        self.nombre = nombre

    def presentarse(self):
        return f"Yo me llamo {self.nombre} y puedo controlar mentes."


heroe = Heroe("Pepe")
villano = Villano("juan")

print(heroe.presentarse())
print(villano.presentarse())
# Out:
# Yo me llamo Pepe y tengo super fuerza.
# Yo me llamo juan y puedo controlar mentes.
