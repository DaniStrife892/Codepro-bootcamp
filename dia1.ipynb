# %%
print('hola mundo')
# Out:
# hola mundo

# %%
# orden de ejecucion
Fruta= 'naranja'
print(Fruta)

Cantidad_de_frutas = 4
print(Cantidad_de_frutas) 

Fruta = 'banana'
print(Fruta)
# Out:
# naranja
# 4
# banana

# %% [markdown]
# # tipos de datos

# %%
edad = 28 #--> integer
altura = 1.80 # --> float
nombre = 'maggi' #--> string
feliz = True #bool

# print(nombre)
# print(edad)
# print(altura)
# print(feliz)
print(nombre,edad,altura,feliz)
# Out:
# maggi 28 1.8 True

# %%
Edad = 18 
ciudad= 'lambare ' 
nombre = 'Dani' 

print("Hola soy", nombre, "tengo", Edad, "años y vivo en", ciudad)
# Out:
# Hola soy Dani tengo 18 años y vivo en lambare

# %%
cantidad_de_manzanas= 2
cantidad_de_naranjas= 2

cantidad_de_frutas= cantidad_de_manzanas + cantidad_de_naranjas
print(Cantidad_de_frutas)
# Out:
# 4

# %%
frutas_vendidas= 4
cantidad_de_frutas = 10

frutas_restantes = cantidad_de_frutas - frutas_vendidas
print(frutas_restantes)
# Out:
# 6

# %%
nombre = 'dani'
apellido = 'valdez'
espacio = ' '
edad = 19
saludo_uno = 'Hola. Me llamo'
saludo_dos ='Mucho gusto'
print (nombre)
print(apellido)
print(nombre + espacio + apellido)
 
print(saludo_uno+espacio+nombre+espacio+apellido+espacio+saludo_dos)
# Out:
# dani
# valdez
# dani valdez
# Hola. Me llamo dani valdez Mucho gusto

# %%
Nombre = input ('escribe tu Nombre')
print(Nombre)
# Out:
# masivo

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))

suma = num1 + num2

print("La suma de los dos números es:", suma)
# Out:
# La suma de los dos números es: 10

# %%
def preparar_sandwich():
    print('preparar_sandwich')
    print('ya el sandwich esta casi listo')
# aqui termina la funcion
#llamar a la funcion
preparar_sandwich()
preparar_sandwich()
# Out:
# preparar_sandwich
# ya el sandwich esta casi listo
# preparar_sandwich
# ya el sandwich esta casi listo

# %%
def Dibujar():
    print('empezando los trazos')
    print('terminando borrador')
    print('terminando las lineas ')
    print('dibujo terminado')

#

Dibujar()
Dibujar()
Dibujar()
# Out:
# empezando los trazos
# terminando borrador
# terminando las lineas
# dibujo terminado
# empezando los trazos
# terminando borrador
# terminando las lineas
# dibujo terminado
# empezando los trazos
# terminando borrador
# terminando las lineas
# dibujo terminado

# %%
def comprar_elemento():
    nombre=input('buenas!, el sabor de helado que desea es?')
    nombre2=input('el precio es de 30 mil gs el kilo, desea adquirirlo')
    nombre3=input('por favor ingrese su metodo de pago')
    nombre4=('muchas gracias por su orden, que disfrute del producto')

    print(nombre)
    print(nombre2)
    print(nombre3)
  
  
    print(nombre4)

comprar_elemento()
comprar_elemento()
comprar_elemento()
# Out:
# frutilla
# si
# tarjeta
# muchas gracias por su orden, que disfrute del producto
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 13
#      10     print(nombre4)
#      12 comprar_elemento()
# ---> 13 comprar_elemento()
#      14 comprar_elemento()
#
# Cell In[16], line 2, in comprar_elemento()
#       1 def comprar_elemento():
# ----> 2     nombre=input('buenas!, el sabor de helado que desea es?')
#       3     nombre2=input('el precio es de 30 mil gs el kilo, desea adquirirlo')
#       4     nombre3=input('por favor ingrese su metodo de pago')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1473, in Kernel.raw_input(self, prompt)
#    1471     msg = "raw_input was called, but this frontend does not support input requests."
#    1472     raise StdinNotImplementedError(msg)
# -> 1473 return self._input_request(
# ...

# %%
pulgadas = input("¿Cuántas pulgadas es la television")
def preguntar():
    resolucion = input("¿Cuál es la resolución que tiene la TV")
    print(f"La TV tiene {pulgadas} pulgadas y una resolucion de {resolucion}")

preguntar()
